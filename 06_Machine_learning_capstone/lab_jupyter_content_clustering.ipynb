# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork32585014-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Clustering based Course Recommender System**

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# Previously, we have generated user profile vectors based on course ratings and genres.
#
# A user profile vector may look like a row vector in the following matrix, for example, we can see the Database column for user2 has a value 1 which means user2 is very interesting in courses related to the databases. With the user profile vectors generated, we can also easily compute the similarity among users based on their shared interests.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/userprofiles.png)

# %% [markdown]
# Furthermore, we could perform clustering algorithms such as K-means or DBSCAN to group users with similar learning interests. For example, in the below user clusters, we have user clusters whom have learned courses related to machine learning, cloud computing, databases, and web development, etc.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/userprofiles_clustering.png)

# %% [markdown]
# For each user group, we can come up with a list of popular courses. For example, for the machine learning user cluster/learning group, we can count the most frequently enrolled courses, which are very likely to be the most popular and good machine learning courses because they are enrolled by many users who are interested in machine learning.
#
# If we know a user belongs to the machine learning group, we may recommend the most enrolled courses to them and it is very likely the user will be interested in them.

# %% [markdown]
# Next in this lab, you will be implementing some clustering-based recommender system algorithms.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# *   Perform k-means clustering on the original user profile feature vectors
# *   Apply PCA (Principle Component Analysis ) on user profile feature vectors to reduce dimensions
# *   Perform k-means clustering on the PCA transformed main components
# *   Generate course recommendations based on other group members' enrollment history

# %% [markdown]
# ***

# %% [markdown]
# ## Prepare and setup lab environment

# %% [markdown]
# First install and import required libraries:

# %%
# !pip install scikit-learn==1.0.2
# !pip install seaborn==0.11.1
# Out:
# zsh:1: command not found: pip
# zsh:1: command not found: pip

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# also set a random state
rs = 123

# %% [markdown]
# ### Load the user profile dataset

# %% [markdown]
# Let's first load the original user profile feature vectors:

# %%
user_profile_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/user_profile.csv"
user_profile_df = pd.read_csv(user_profile_url)
user_profile_df.head()
# Out:
#    user  Database  Python  CloudComputing  DataAnalysis  Containers  \
# 0     2      52.0    14.0             6.0          43.0         3.0
# 1     4      40.0     2.0             4.0          28.0         0.0
# 2     5      24.0     8.0            18.0          24.0         0.0
# 3     7       2.0     0.0             0.0           2.0         0.0
# 4     8       6.0     0.0             0.0           4.0         0.0
#
#    MachineLearning  ComputerVision  DataScience  BigData  Chatbot     R  \
# 0             33.0             0.0         29.0     41.0      2.0  18.0
# 1             14.0             0.0         20.0     24.0      0.0   6.0
# 2             30.0             0.0         22.0     14.0      2.0  14.0
# 3              0.0             0.0          0.0      2.0      0.0   0.0
# 4              0.0             0.0          0.0      6.0      0.0   2.0
#
#    BackendDev  FrontendDev  Blockchain
# 0        34.0          9.0         6.0
# 1         6.0          0.0         2.0
# 2        26.0          4.0         6.0
# 3         0.0          0.0         0.0
# 4         0.0          0.0         0.0

# %%
user_profile_df.shape
# Out:
# (33901, 15)

# %% [markdown]
# we can then list the feature names, they are the user interested topics (course genres):

# %%
feature_names = list(user_profile_df.columns[1:])
feature_names
# Out:
# ['Database',
#  'Python',
#  'CloudComputing',
#  'DataAnalysis',
#  'Containers',
#  'MachineLearning',
#  'ComputerVision',
#  'DataScience',
#  'BigData',
#  'Chatbot',
#  'R',
#  'BackendDev',
#  'FrontendDev',
#  'Blockchain']

# %% [markdown]
# As we can see from the user profile dataset, we have about 33K unique users with interests in areas like `Database`, `Python`, `CloudComputing`, etc. Then, let's check the  summary statistics for each feature.

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  33901.000000  33901.000000    33901.000000  33901.000000
# mean   1.064064e+06      5.518569      3.493791        2.307100      3.624701
# std    4.972578e+05      7.611941      4.227254        3.841858      4.760135
# min    2.000000e+00      0.000000      0.000000        0.000000      0.000000
# 25%    6.813480e+05      0.000000      0.000000        0.000000      0.000000
# 50%    1.043907e+06      3.000000      3.000000        0.000000      3.000000
# 75%    1.451159e+06      9.000000      6.000000        3.000000      6.000000
# max    2.103039e+06     63.000000     18.000000       38.000000     48.000000
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  33901.000000     33901.000000    33901.000000  33901.000000
# mean       0.998938         3.048022        0.001770      5.087343
# std        2.351764         4.624004        0.072846      5.230697
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      3.000000
# 75%        0.000000         3.000000        0.000000      9.000000
# max       15.000000        39.000000        3.000000     32.000000
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  33901.000000  33901.000000  33901.000000  33901.000000  33901.000000
# mean       4.750450      0.462995      1.017433      2.269461      0.315802
# std        7.216228      1.055186      2.342532      4.310752      1.363462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      0.000000      0.000000      0.000000      0.000000
# 75%        6.000000      0.000000      0.000000      3.000000      0.000000
# max       54.000000      6.000000     18.000000     54.000000     15.000000
#
#          Blockchain
# count  33901.000000
# mean       0.986844
# std        1.950585
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000

# %% [markdown]
# The original user profile feature vector is not normalized, which may cause issues when we perform clustering and Principal component analysis (PCA), therefor we standardize the data.

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
scaler = StandardScaler()
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df[feature_names])
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(),user_profile_df[feature_names].std()))
# Out:
# mean Database          -3.353495e-17
# Python            -5.700942e-17
# CloudComputing    -3.521170e-17
# DataAnalysis      -7.671120e-17
# Containers         3.353495e-18
# MachineLearning    3.688845e-17
# ComputerVision    -1.509073e-17
# DataScience       -1.676748e-17
# BigData            6.706990e-17
# Chatbot           -6.874665e-17
# R                  4.233788e-17
# BackendDev         1.383317e-17
# FrontendDev        5.051202e-17
# Blockchain        -5.281755e-17
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  3.390100e+04  3.390100e+04    3.390100e+04  3.390100e+04
# mean   1.064064e+06 -3.353495e-17 -5.700942e-17   -3.521170e-17 -7.671120e-17
# std    4.972578e+05  1.000015e+00  1.000015e+00    1.000015e+00  1.000015e+00
# min    2.000000e+00 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 25%    6.813480e+05 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 50%    1.043907e+06 -3.308757e-01 -1.168130e-01   -6.005256e-01 -1.312380e-01
# 75%    1.451159e+06  4.573712e-01  5.928781e-01    1.803581e-01  4.990056e-01
# max    2.103039e+06  7.551593e+00  3.431642e+00    9.290667e+00  9.322416e+00
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  3.390100e+04     3.390100e+04    3.390100e+04  3.390100e+04
# mean   3.353495e-18     3.688845e-17   -1.509073e-17 -1.676748e-17
# std    1.000015e+00     1.000015e+00    1.000015e+00  1.000015e+00
# min   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 25%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 50%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -3.990622e-01
# 75%   -4.247674e-01    -1.038556e-02   -2.429612e-02  7.480294e-01
# max    5.953517e+00     7.775190e+00    4.115884e+01  5.145214e+00
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04
# mean   6.706990e-17 -6.874665e-17  4.233788e-17  1.383317e-17  5.051202e-17
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 25%   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 50%   -3.811535e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 75%    1.731609e-01 -4.387873e-01 -4.343370e-01  1.694715e-01 -2.316212e-01
# max    6.824934e+00  5.247500e+00  7.249771e+00  1.200053e+01  1.076995e+01
#
#          Blockchain
# count  3.390100e+04
# mean  -5.281755e-17
# std    1.000015e+00
# min   -5.059295e-01
# 25%   -5.059295e-01
# 50%   -5.059295e-01
# 75%    5.194189e-01
# max    5.646161e+00

# %% [markdown]
# The normalized user profile features are:

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
features
# Out:
#        Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0      6.106474  2.485388        0.961242      8.272010    0.850889
# 1      4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2      2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4      0.063248 -0.826504       -0.600526      0.078843   -0.424767
# ...         ...       ...             ...           ...         ...
# 33896 -0.330876 -0.116813        0.180358      0.499006   -0.424767
# 33897 -0.724999 -0.826504       -0.079936     -0.761482   -0.424767
# 33898 -0.330876  0.592878        0.961242     -0.761482   -0.424767
# 33899 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
# 33900 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
#
#        MachineLearning  ComputerVision  DataScience   BigData   Chatbot  \
# 0             6.477594       -0.024296     4.571668  5.023412  1.456642
# 1             2.368540       -0.024296     2.851031  2.667576 -0.438787
# 2             5.828796       -0.024296     3.233395  1.281790  1.456642
# 3            -0.659184       -0.024296    -0.972608 -0.381153 -0.438787
# 4            -0.659184       -0.024296    -0.972608  0.173161 -0.438787
# ...                ...             ...          ...       ...       ...
# 33896        -0.659184       -0.024296     0.174484 -0.658311 -0.438787
# 33897        -0.659184       -0.024296    -0.972608 -0.658311 -0.438787
# 33898         2.368540       -0.024296     0.748029 -0.658311 -0.438787
# 33899        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
# 33900        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
#
#               R  BackendDev  FrontendDev  Blockchain
# 0      7.249771    7.360899     6.369323    2.570116
# 1      2.127032    0.865416    -0.231621    0.519419
# 2      5.542191    5.505047     2.702132    2.570116
# 3     -0.434337   -0.526473    -0.231621   -0.505930
# 4      0.419453   -0.526473    -0.231621   -0.505930
# ...         ...         ...          ...         ...
# 33896  2.127032    0.865416    -0.231621    1.032093
# 33897 -0.434337   -0.526473    -0.231621   -0.505930
# 33898  0.846348   -0.526473    -0.231621   -0.505930
# 33899 -0.434337   -0.526473    -0.231621   -0.505930
# 33900 -0.434337   -0.526473    -0.231621   -0.505930
#
# [33901 rows x 14 columns]

# %% [markdown]
# we can also save the user ids for later recommendation tasks:

# %%
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
user_ids
# Out:
#           user
# 0            2
# 1            4
# 2            5
# 3            7
# 4            8
# ...        ...
# 33896  2102054
# 33897  2102356
# 33898  2102680
# 33899  2102983
# 33900  2103039
#
# [33901 rows x 1 columns]

# %% [markdown]
# ### TASK: Perform K-means clustering algorithm on the user profile feature vectors

# %% [markdown]
# With the user profile dataset ready, you need to use the `KMeans` class provided by scikit-learn library to perform clustering on the user profile feature vectors.

# %% [markdown]
# For `KMeans` algorithm, one important hyperparameter is the number of clusters `n_cluster`, and a good way to find the optimized `n_cluster` is using to grid search a list of candidates and find the one with the best or optimized clustering evaluation metrics such as minimal `sum of squared distance`:

# %% [markdown]
# *TODO: grid search the optimized n_cluster for KMeans() model*

# %%
# WRITE YOUR CODE HERE
inertia = []
list_num_clusters = list(range(1,30))
for num_clusters in list_num_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(features)
    inertia.append(km.inertia_)
    
plt.plot(list_num_clusters,inertia)
plt.scatter(list_num_clusters,inertia)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia');

# Find an optimized number of neighors k from a candidate list such as list_k = list(range(1, 30))

# %% [markdown]
# If you plot the grid search process, you may get a elbow plot like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/clusters_elbow.png)

# %% [markdown]
# From the elbow plot, you should visualy identify the point where the metric starting to be flatten, which indicates the optimized number of clusters.

# %% [markdown]
# Once you have identified the best number of clusters, you can apply `KMeans()` again to generate cluster label for all users.

# %%
cluster_labels = [None] * len(user_ids)

# %% [markdown]
# *TODO: Apply KMeans() on the features with optimized n_cluster parameter after model fitting, you can find output cluster labels in `model.labels_` attribute*

# %%
## WRITE YOUR CODE HERE
km = KMeans(n_clusters=10)
km.fit(features)
## ...
cluster_labels = km.labels_
## ...
cluster_labels
# Out:
# array([0, 0, 0, ..., 8, 4, 4], dtype=int32)

# %% [markdown]
# The cluster labels you generated is a list of integers indicating cluster indices. You may use the following utility method to combine the cluster labels and user ids to a dataframe, so that you know which cluster a user belongs:

# %%
def combine_cluster_labels(user_ids, labels):
    labels_df = pd.DataFrame(labels)
    cluster_df = pd.merge(user_ids, labels_df, left_index=True, right_index=True)
    cluster_df.columns = ['user', 'cluster']
    return cluster_df

# %%
a=combine_cluster_labels(user_ids,cluster_labels)
a
# Out:
#           user  cluster
# 0            2        0
# 1            4        0
# 2            5        0
# 3            7        4
# 4            8        4
# ...        ...      ...
# 33896  2102054        1
# 33897  2102356        4
# 33898  2102680        8
# 33899  2102983        4
# 33900  2103039        4
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results may look like the following screenshot:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/cluster_labels.png)

# %% [markdown]
# Now, each user finds its own cluster or we can say we have created many clusters of learning communities. Learners within each community share very similar learning interests.

# %% [markdown]
# ### TASK: Apply PCA on user profile feature vectors to reduce dimensions

# %% [markdown]
# In the previous step, we applied `KMeans` on the original user profile feature vectors which have 14 original features (the course genres).

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
feature_names = list(user_profile_df.columns[1:])

# %%
print(f"There are {len(feature_names)} features for each user profile.")
# Out:
# There are 14 features for each user profile.

# %% [markdown]
# If we plot a covariance matrix of the user profile feature vectors with 14 features, we can observe that some features are actually correlated:

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = features.cov()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


plt.show()

# %% [markdown]
# For example, the feature `MachineLearning` and the feature `DataScience` are correlated. Such covariances among features may indicate that we can apply PCA to find its main components (eigenvectors with max eigenvalues on the covariance matrix).
#
# If we only keep the independent main components, then we can reduce the dimensions of our user profile feature vectors.

# %% [markdown]
# Now let's apply the `PCA()` provided by  `scikit-learn` to find the main components in user profile feature vectors and see if we can reduce its dimensions by only keeping the main components.

# %% [markdown]
# Note that when calling the  `PCA()` class, there is also an import argument called `n_components` which indicates how many components you want to keep in the PCA result. One way to find an optimized `n_components` is to do a grid search on a list of argument candidates (such as `range(1, 15)`) and calculate the ratio of the accumulated variance for each candidate.
#
# If the accumulated variances ratio of a candidate `n_components` is larger than a threshold, e.g., 90%, then we can say the transformed `n_components` could explain about 90% of variances of the original data variance and can be considered as an optimized components size.

# %% [markdown]
# *TODO: Find the optimized `n_components` for PCA*

# %%
# WRITE YOUR CODE HERE
from sklearn.decomposition import PCA

pca_list = list()
feature_weight_list = list()

# Fit a range of PCA models

for n in range(1, 14):
    
    # Create and fit the model
    PCAmod = PCA(n_components=n)
    PCAmod.fit(features)
    
    # Store the model and variance
    pca_list.append(pd.Series({'n':n, 'model':PCAmod,
                               'var': PCAmod.explained_variance_ratio_.sum()}))
    
    # Calculate and store feature importances
    abs_feature_values = np.abs(PCAmod.components_).sum(axis=0)
    feature_weight_list.append(pd.DataFrame({'n':n, 
                                             'features': features.columns,
                                             'values':abs_feature_values/abs_feature_values.sum()}))
    
pca_df = pd.concat(pca_list, axis=1).T.set_index('n')
pca_df
# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                    model       var
# n
# 1    PCA(n_components=1)  0.287568
# 2    PCA(n_components=2)  0.463093
# 3    PCA(n_components=3)  0.576134
# 4    PCA(n_components=4)  0.648747
# 5    PCA(n_components=5)  0.719488
# 6    PCA(n_components=6)   0.78821
# 7    PCA(n_components=7)  0.842956
# 8    PCA(n_components=8)  0.894445
# 9    PCA(n_components=9)   0.92727
# 10  PCA(n_components=10)  0.954466
# 11  PCA(n_components=11)  0.973357
# 12  PCA(n_components=12)  0.987031
# 13  PCA(n_components=13)  0.997916

# %%
sns.set_context('talk')
ax = pca_df['var'].plot(kind='bar')

ax.set(xlabel='Number of dimensions',
       ylabel='Percent explained variance',
       title='Explained Variance vs Dimensions');

# %% [markdown]
# If you visualize your hyperparameter searching process, you may get a trend line like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/pca.png)

# %% [markdown]
# Once you found the optimized `n_component` argument value, you can apply PCA on the user profile feature vectors and reduce the  14 features into  `n_component` features.

# %% [markdown]
# *TODO: Perform PCA to transform original user profile features*

# %%
# WRITE YOUR CODE HERE
PCAmod = PCA(n_components=9)
data_pipe=PCAmod.fit_transform(features)

data_pipe=pd.DataFrame(data_pipe)
#data_pipe['user']=user_ids
#data_pipe.columns=['PC0','PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','user']

# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
# - Merge the user ids and transformed features into a new dataframe

# %%
data_pipe
# Out:
#                0         1         2         3         4         5         6  \
# 0      17.772494  0.200681  1.730609  2.567359 -3.825814  2.707154  0.681042
# 1       7.145199 -2.847481  2.358636 -0.576654  0.398803 -0.134533  0.549769
# 2      11.363270  1.873619 -1.522077  1.076144 -1.711688  0.883212  1.677582
# 3      -1.834033 -0.277462  0.564905  0.053470 -0.064440  0.165757  0.030956
# 4      -1.049125 -0.684767  1.072765  0.006371 -0.005695  0.118686  0.118559
# ...          ...       ...       ...       ...       ...       ...       ...
# 33896   0.633824  0.108815 -0.388871 -0.122665 -0.098364  0.358333  1.752049
# 33897  -2.095339  0.135058  0.244727 -0.088185  0.025081  0.183641  0.046413
# 33898   0.625943 -0.547167 -1.692824 -0.630589  0.166632  0.676244 -0.055100
# 33899  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109  0.072496
# 33900  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109  0.072496
#
#               7         8
# 0      2.312613  0.868272
# 1      0.469033  0.033405
# 2      2.937669  2.097639
# 3      0.039519  0.210887
# 4      0.559292  0.186379
# ...         ...       ...
# 33896  1.486542 -0.523600
# 33897  0.191709  0.260437
# 33898  0.582091  1.703193
# 33899  0.113750  0.622900
# 33900  0.113750  0.622900
#
# [33901 rows x 9 columns]

# %% [markdown]
# Your PCA transformed dataframe may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/pca_res.png)

# %% [markdown]
# ### TASK: Perform k-means clustering on the PCA transformed feature vectors

# %% [markdown]
# Now, you have the PCA  components of the original profile vectors. You can perform k-means on them again:

# %% [markdown]
# *TODO: Perform K-means on the PCA transformed features*

# %%
## WRITE YOUR CODE HERE
## WRITE YOUR CODE HERE
km = KMeans(n_clusters=10)
km.fit(data_pipe)
## ...
cluster_labels = km.labels_
## ...
cluster_labels
a=combine_cluster_labels(user_ids,cluster_labels)
a

## - Apply KMeans() on the PCA features
## - Obtain the cluster label lists from model.labels_ attribute
## - Assign each user a cluster label by combining user ids and cluster labels
# Out:
#           user  cluster
# 0            2        2
# 1            4        2
# 2            5        2
# 3            7        0
# 4            8        0
# ...        ...      ...
# 33896  2102054        1
# 33897  2102356        0
# 33898  2102680        9
# 33899  2102983        0
# 33900  2103039        0
#
# [33901 rows x 2 columns]

# %% [markdown]
# Your clustering results should have the same format as the k-means on the original dataset:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/cluster_labels.png)

# %% [markdown]
# Great, now all users find their learning interest groups, either based on their original or the PCA transformed user profile features.

# %% [markdown]
# When a user is in a group or a community, it is very likely that the user will be interested in the courses enrolled by other members within the same group.

# %% [markdown]
# ### TASK: Generate course recommendations based on the popular courses in the same cluster

# %% [markdown]
# The Intuition of clustering-based course recommendation is very simple and can be illustrated via the following example:

# %% [markdown]
# Suppose a user has joined a machine learning group (via clustering algorithm). In the group, he/she finds that the top-3 courses enrolled by all other group members are `Machine Learning for Everyone`, `Machine Learning with Python`, `Machine Learning with Scikit-learn`. Since the user has already completed the `Machine Learning for Everyone` earlier, he/she decides to trust the group members' choices and enroll in other two unselected courses `Machine Learning with Python` and `Machine Learning with Scikit-learn`.

# %% [markdown]
# In summary, the clustering-based recommender system first groups all users based on their profiles, and maintains a popular courses list for each group.
#
# For any group member who needs course recommendations, the algorithm recommends the unselected courses from the popular course lists.

# %% [markdown]
# Next, suppose we have a set of test users, and we want to recommend new courses to them using a clustering-based recommender system:

# %%
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]
test_users_df.head()
# Out:
#       user      item
# 0  1502801  RP0105EN
# 1  1609720  CNSC02EN
# 2  1347188  CO0301EN
# 3   755067  ML0103EN
# 4   538595  BD0115EN

# %% [markdown]
# The test users dataset has only two columns, the user id and the enrolled course id.

# %% [markdown]
# For each user, let's find its cluster label using the k-means results you have performed in previous steps, assuming it is named `cluster_df`.

# %% [markdown]
# You can assign the cluster label to all test users via merging the clustering labels (`cluster_df`:):

# %%
test_users_labelled = pd.merge(test_users_df, a, left_on='user', right_on='user')
test_users_labelled
# Out:
#          user      item  cluster
# 0     1502801  RP0105EN        5
# 1     1502801  BD0131EN        5
# 2     1502801  BD0212EN        5
# 3     1502801  BD0115EN        5
# 4     1502801  BD0211EN        5
# ...       ...       ...      ...
# 9397   630511  BD0121EN        0
# 9398   630511  SC0101EN        0
# 9399   630511  BD0111EN        0
# 9400   630511  BD0115EN        0
# 9401   630511  PY0101EN        0
#
# [9402 rows x 3 columns]

# %% [markdown]
# The merged the test dataset may look like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module\_3/images/test_users_label.png)

# %% [markdown]
# From the above dataframe, we know each user's enrolled courses and its cluster index.

# %% [markdown]
# If we use a `groupby`  and `sum` aggregation, we can get the enrollments count for each course in each group, like the following code snippet:

# %%
courses_cluster = test_users_labelled[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
# Out:
#      cluster      item  enrollments
# 0          0  AI0111EN            3
# 1          0  BC0101EN           36
# 2          0  BC0201EN           19
# 3          0  BC0202EN            3
# 4          0  BD0101EN           99
# ..       ...       ...          ...
# 710        9  SW0201EN            1
# 711        9    TA0105            3
# 712        9  TA0105EN           13
# 713        9  TA0106EN            2
# 714        9  WA0101EN           11
#
# [715 rows x 3 columns]

# %% [markdown]
# *TODO: For each test user, try to recommend any unseen courses based on the popular courses in his/her cluster. You may use an enrollment count threshold (such as larger than 10) to determine if it is a popular course in the cluster*

# %%
## WRITE YOUR CODE HERE
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]

#test_users_df=test_users_df.head(1)

## - For each user, first finds its cluster label
test_users_labelled = pd.merge(test_users_df, a, left_on='user', right_on='user')

courses_cluster = test_users_labelled[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
popularcourses=courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
popularcourses=popularcourses[popularcourses['enrollments']>100]

usuariosunicos=test_users_labelled[['user','cluster']].drop_duplicates()
#popularcourses
recomendacionesFinales=[]
    ## - First get all courses belonging to the same cluster and figure out what are the popular ones (such as course enrollments beyond a threshold like 100)
for index in usuariosunicos.index:#[['item', 'cluster']]:
  
    recomendaciones=popularcourses[popularcourses['cluster']==usuariosunicos['cluster'][index]]
    ## - Get the user's current enrolled courses
    currentcourses=test_users_labelled[test_users_labelled['user']==usuariosunicos['user'][index]]
    ## - Check if there are any courses on the popular course list which are new/unseen to the user. 
  
    
    for x in recomendaciones['item']:
        if x not in currentcourses['item'].values:
            recomendacionesFinales.append({'user':usuariosunicos['user'][index],'item':x})
            break
    
    #recomendacionesFinales=recomendaciones
    ## If yes, make those unseen and popular courses as recommendation results for the user

recomendacionesFinales
# Out:
# [{'user': 1609720, 'item': 'PY0101EN'},
#  {'user': 755067, 'item': 'BD0111EN'},
#  {'user': 538595, 'item': 'BD0211EN'},
#  {'user': 1773079, 'item': 'DS0101EN'},
#  {'user': 1122903, 'item': 'DS0101EN'},
#  {'user': 1351020, 'item': 'DA0101EN'},
#  {'user': 472908, 'item': 'DS0101EN'},
#  {'user': 482875, 'item': 'BD0211EN'},
#  {'user': 1541383, 'item': 'DS0101EN'},
#  {'user': 877026, 'item': 'DA0101EN'},
#  {'user': 913275, 'item': 'BD0101EN'},
#  {'user': 985429, 'item': 'ML0101ENv3'},
#  {'user': 1237626, 'item': 'DA0101EN'},
#  {'user': 1378699, 'item': 'DS0101EN'},
#  {'user': 762860, 'item': 'ML0101ENv3'},
#  {'user': 1194679, 'item': 'BD0101EN'},
#  {'user': 759038, 'item': 'BD0101EN'},
#  {'user': 1715864, 'item': 'ML0101ENv3'},
#  {'user': 738131, 'item': 'DS0101EN'},
#  {'user': 1271375, 'item': 'DS0101EN'},
#  {'user': 1538828, 'item': 'DV0101EN'},
#  {'user': 1006163, 'item': 'DV0101EN'},
#  {'user': 2021696, 'item': 'DS0101EN'},
#  {'user': 1521903, 'item': 'DS0101EN'},
#  {'user': 887336, 'item': 'DS0101EN'},
#  {'user': 1206954, 'item': 'DV0101EN'},
#  {'user': 560247, 'item': 'BD0211EN'},
#  {'user': 2004142, 'item': 'DV0101EN'},
#  {'user': 1078030, 'item': 'DS0101EN'},
#  {'user': 621543, 'item': 'BD0211EN'},
#  {'user': 2022708, 'item': 'DS0101EN'},
#  {'user': 627837, 'item': 'ML0101ENv3'},
#  {'user': 1208551, 'item': 'DV0101EN'},
#  {'user': 1391909, 'item': 'DA0101EN'},
#  {'user': 1571241, 'item': 'ML0101ENv3'},
#  {'user': 1457700, 'item': 'DS0101EN'},
#  {'user': 1273446, 'item': 'BD0101EN'},
#  {'user': 968795, 'item': 'BD0101EN'},
#  {'user': 1788961, 'item': 'DA0101EN'},
#  {'user': 696942, 'item': 'BD0211EN'},
#  {'user': 1688652, 'item': 'BD0101EN'},
#  {'user': 1593639, 'item': 'DS0101EN'},
#  {'user': 1819037, 'item': 'DS0101EN'},
#  {'user': 1107112, 'item': 'DS0101EN'},
#  {'user': 2046621, 'item': 'DS0101EN'},
#  {'user': 1806813, 'item': 'ML0101ENv3'},
#  {'user': 1573190, 'item': 'DA0101EN'},
#  {'user': 750640, 'item': 'DS0101EN'},
#  {'user': 748522, 'item': 'BD0101EN'},
#  {'user': 886688, 'item': 'DS0101EN'},
#  {'user': 883150, 'item': 'DA0101EN'},
#  {'user': 142685, 'item': 'DS0101EN'},
#  {'user': 897866, 'item': 'BD0211EN'},
#  {'user': 1691129, 'item': 'CB0103EN'},
#  {'user': 1697791, 'item': 'DS0101EN'},
#  {'user': 931463, 'item': 'DS0101EN'},
#  {'user': 1831780, 'item': 'DA0101EN'},
#  {'user': 702927, 'item': 'DS0101EN'},
#  {'user': 1608895, 'item': 'DA0101EN'},
#  {'user': 1300715, 'item': 'DS0101EN'},
#  {'user': 1008779, 'item': 'ML0101ENv3'},
#  {'user': 1167173, 'item': 'DS0101EN'},
#  {'user': 2082818, 'item': 'DS0101EN'},
#  {'user': 1607052, 'item': 'DA0101EN'},
#  {'user': 1758635, 'item': 'DS0101EN'},
#  {'user': 1667543, 'item': 'DS0101EN'},
#  {'user': 2036996, 'item': 'DS0101EN'},
#  {'user': 425952, 'item': 'BD0111EN'},
#  {'user': 934060, 'item': 'DS0101EN'},
#  {'user': 418401, 'item': 'DA0101EN'},
#  {'user': 779324, 'item': 'DA0101EN'},
#  {'user': 1390701, 'item': 'DA0101EN'},
#  {'user': 70434, 'item': 'DS0101EN'},
#  {'user': 620994, 'item': 'DA0101EN'},
#  {'user': 52091, 'item': 'DS0101EN'},
#  {'user': 1443238, 'item': 'DS0101EN'},
#  {'user': 1562232, 'item': 'DS0101EN'},
#  {'user': 615039, 'item': 'DA0101EN'},
#  {'user': 1738888, 'item': 'BD0211EN'},
#  {'user': 428830, 'item': 'BD0211EN'},
#  {'user': 1514188, 'item': 'DS0101EN'},
#  {'user': 667110, 'item': 'BD0211EN'},
#  {'user': 483426, 'item': 'DS0101EN'},
#  {'user': 506734, 'item': 'BD0211EN'},
#  {'user': 211118, 'item': 'DS0101EN'},
#  {'user': 1977334, 'item': 'DV0101EN'},
#  {'user': 464965, 'item': 'BD0211EN'},
#  {'user': 1696376, 'item': 'DA0101EN'},
#  {'user': 774617, 'item': 'DS0101EN'},
#  {'user': 1083088, 'item': 'DS0101EN'},
#  {'user': 942027, 'item': 'DA0101EN'},
#  {'user': 1751031, 'item': 'DS0101EN'},
#  {'user': 277715, 'item': 'DS0101EN'},
#  {'user': 718368, 'item': 'BD0211EN'},
#  {'user': 1441107, 'item': 'DS0101EN'},
#  {'user': 1087982, 'item': 'DA0101EN'},
#  {'user': 642609, 'item': 'BD0211EN'},
#  {'user': 491004, 'item': 'BD0101EN'},
#  {'user': 1824570, 'item': 'DA0101EN'},
#  {'user': 354686, 'item': 'BD0101EN'},
#  {'user': 608432, 'item': 'BD0211EN'},
#  {'user': 1018679, 'item': 'DS0101EN'},
#  {'user': 1393591, 'item': 'DA0101EN'},
#  {'user': 911798, 'item': 'ML0101ENv3'},
#  {'user': 1040249, 'item': 'DS0101EN'},
#  {'user': 1327565, 'item': 'DA0101EN'},
#  {'user': 1106139, 'item': 'DS0101EN'},
#  {'user': 1766896, 'item': 'DS0101EN'},
#  {'user': 786514, 'item': 'BD0211EN'},
#  {'user': 1050603, 'item': 'DS0101EN'},
#  {'user': 1804257, 'item': 'DS0101EN'},
#  {'user': 446388, 'item': 'DS0101EN'},
#  {'user': 795406, 'item': 'BD0101EN'},
#  {'user': 551330, 'item': 'DS0101EN'},
#  {'user': 899822, 'item': 'DS0101EN'},
#  {'user': 545870, 'item': 'DA0101EN'},
#  {'user': 1428322, 'item': 'DA0101EN'},
#  {'user': 435898, 'item': 'DS0101EN'},
#  {'user': 1713082, 'item': 'DS0101EN'},
#  {'user': 1029144, 'item': 'DS0101EN'},
#  {'user': 1143528, 'item': 'DA0101EN'},
#  {'user': 1562460, 'item': 'DS0101EN'},
#  {'user': 1455180, 'item': 'DS0101EN'},
#  {'user': 924246, 'item': 'DS0101EN'},
#  {'user': 476798, 'item': 'DS0101EN'},
#  {'user': 1594142, 'item': 'DV0101EN'},
#  {'user': 1719220, 'item': 'ML0101ENv3'},
#  {'user': 1326774, 'item': 'DA0101EN'},
#  {'user': 585654, 'item': 'DV0101EN'},
#  {'user': 607310, 'item': 'DA0101EN'},
#  {'user': 477953, 'item': 'BD0101EN'},
#  {'user': 1271384, 'item': 'DS0101EN'},
#  {'user': 134697, 'item': 'DS0101EN'},
#  {'user': 536821, 'item': 'DA0101EN'},
#  {'user': 1691061, 'item': 'DV0101EN'},
#  {'user': 403519, 'item': 'BD0211EN'},
#  {'user': 1190880, 'item': 'DV0101EN'},
#  {'user': 2074313, 'item': 'ML0101ENv3'},
#  {'user': 724221, 'item': 'DA0101EN'},
#  {'user': 902488, 'item': 'DA0101EN'},
#  {'user': 506042, 'item': 'BD0101EN'},
#  {'user': 1448499, 'item': 'ML0101ENv3'},
#  {'user': 781728, 'item': 'BD0211EN'},
#  {'user': 1322106, 'item': 'ML0101ENv3'},
#  {'user': 553969, 'item': 'BD0101EN'},
#  {'user': 691859, 'item': 'DS0101EN'},
#  {'user': 1098265, 'item': 'BD0101EN'},
#  {'user': 574414, 'item': 'BD0101EN'},
#  {'user': 1325797, 'item': 'DA0101EN'},
#  {'user': 1581358, 'item': 'DA0101EN'},
#  {'user': 306665, 'item': 'DS0101EN'},
#  {'user': 889030, 'item': 'DS0101EN'},
#  {'user': 1625299, 'item': 'DS0101EN'},
#  {'user': 271899, 'item': 'BD0211EN'},
#  {'user': 1045938, 'item': 'DA0101EN'},
#  {'user': 1180577, 'item': 'DS0101EN'},
#  {'user': 345064, 'item': 'DA0101EN'},
#  {'user': 607999, 'item': 'DS0101EN'},
#  {'user': 1411199, 'item': 'DA0101EN'},
#  {'user': 1641257, 'item': 'DA0101EN'},
#  {'user': 1571316, 'item': 'DS0101EN'},
#  {'user': 1399082, 'item': 'DA0101EN'},
#  {'user': 1349271, 'item': 'BD0101EN'},
#  {'user': 1267592, 'item': 'DA0101EN'},
#  {'user': 1688004, 'item': 'DS0101EN'},
#  {'user': 1453903, 'item': 'DA0101EN'},
#  {'user': 739646, 'item': 'DS0101EN'},
#  {'user': 203388, 'item': 'DS0101EN'},
#  {'user': 746437, 'item': 'DA0101EN'},
#  {'user': 484628, 'item': 'BD0101EN'},
#  {'user': 1265804, 'item': 'DA0101EN'},
#  {'user': 1076032, 'item': 'DA0101EN'},
#  {'user': 1069780, 'item': 'DS0101EN'},
#  {'user': 1434413, 'item': 'DA0101EN'},
#  {'user': 988310, 'item': 'BD0101EN'},
#  {'user': 785533, 'item': 'DA0101EN'},
#  {'user': 396776, 'item': 'DS0101EN'},
#  {'user': 471338, 'item': 'BD0211EN'},
#  {'user': 1622107, 'item': 'DA0101EN'},
#  {'user': 461359, 'item': 'DV0101EN'},
#  {'user': 351320, 'item': 'BD0111EN'},
#  {'user': 1343288, 'item': 'DA0101EN'},
#  {'user': 1088239, 'item': 'BD0101EN'},
#  {'user': 1308482, 'item': 'DS0101EN'},
#  {'user': 1764803, 'item': 'DA0101EN'},
#  {'user': 1408128, 'item': 'ML0101ENv3'},
#  {'user': 1107439, 'item': 'DS0101EN'},
#  {'user': 613802, 'item': 'BD0111EN'},
#  {'user': 620075, 'item': 'BD0101EN'},
#  {'user': 1086160, 'item': 'DS0101EN'},
#  {'user': 2000884, 'item': 'DA0101EN'},
#  {'user': 1315713, 'item': 'ML0101ENv3'},
#  {'user': 1463405, 'item': 'DA0101EN'},
#  {'user': 1325764, 'item': 'BD0101EN'},
#  {'user': 390213, 'item': 'DS0101EN'},
#  {'user': 181124, 'item': 'BD0111EN'},
#  {'user': 435858, 'item': 'DS0101EN'},
#  {'user': 1864236, 'item': 'DS0101EN'},
#  {'user': 1547165, 'item': 'DS0101EN'},
#  {'user': 1105350, 'item': 'DA0101EN'},
#  {'user': 565505, 'item': 'DS0101EN'},
#  {'user': 1008900, 'item': 'DA0101EN'},
#  {'user': 679194, 'item': 'DA0101EN'},
#  {'user': 1864644, 'item': 'DS0101EN'},
#  {'user': 920511, 'item': 'BD0211EN'},
#  {'user': 1044500, 'item': 'DS0101EN'},
#  {'user': 246282, 'item': 'BD0101EN'},
#  {'user': 1554610, 'item': 'DA0101EN'},
#  {'user': 1076158, 'item': 'ML0101ENv3'},
#  {'user': 902409, 'item': 'DA0101EN'},
#  {'user': 683043, 'item': 'DS0101EN'},
#  {'user': 1346186, 'item': 'DA0101EN'},
#  {'user': 1313389, 'item': 'DV0101EN'},
#  {'user': 1607944, 'item': 'DS0101EN'},
#  {'user': 1904245, 'item': 'DS0101EN'},
#  {'user': 1473132, 'item': 'DS0101EN'},
#  {'user': 1543054, 'item': 'DV0101EN'},
#  {'user': 899096, 'item': 'DA0101EN'},
#  {'user': 85625, 'item': 'BD0101EN'},
#  {'user': 614638, 'item': 'DS0101EN'},
#  {'user': 277197, 'item': 'BD0101EN'},
#  {'user': 1515909, 'item': 'DA0101EN'},
#  {'user': 1808215, 'item': 'DA0101EN'},
#  {'user': 1028691, 'item': 'BD0211EN'},
#  {'user': 786282, 'item': 'BD0211EN'},
#  {'user': 884576, 'item': 'ML0101ENv3'},
#  {'user': 1227916, 'item': 'DS0101EN'},
#  {'user': 1720300, 'item': 'DA0101EN'},
#  {'user': 1009985, 'item': 'DS0101EN'},
#  {'user': 1067028, 'item': 'DS0101EN'},
#  {'user': 1699356, 'item': 'DV0101EN'},
#  {'user': 1687045, 'item': 'DS0101EN'},
#  {'user': 1768789, 'item': 'DS0101EN'},
#  {'user': 1637328, 'item': 'DS0101EN'},
#  {'user': 1133967, 'item': 'DA0101EN'},
#  {'user': 1357226, 'item': 'DS0101EN'},
#  {'user': 666770, 'item': 'BD0211EN'},
#  {'user': 573047, 'item': 'DA0101EN'},
#  {'user': 1650969, 'item': 'DA0101EN'},
#  {'user': 1103515, 'item': 'ML0101ENv3'},
#  {'user': 984164, 'item': 'DS0101EN'},
#  {'user': 1020974, 'item': 'DS0101EN'},
#  {'user': 1305655, 'item': 'DS0101EN'},
#  {'user': 1871037, 'item': 'DV0101EN'},
#  {'user': 1323058, 'item': 'DS0101EN'},
#  {'user': 1356003, 'item': 'DS0101EN'},
#  {'user': 435578, 'item': 'DS0101EN'},
#  {'user': 1060120, 'item': 'DA0101EN'},
#  {'user': 1016704, 'item': 'BD0111EN'},
#  {'user': 1079714, 'item': 'DA0101EN'},
#  {'user': 1944533, 'item': 'CB0103EN'},
#  {'user': 1468344, 'item': 'DA0101EN'},
#  {'user': 1828981, 'item': 'DS0101EN'},
#  {'user': 529858, 'item': 'BD0111EN'},
#  {'user': 1856259, 'item': 'DS0101EN'},
#  {'user': 1916042, 'item': 'DS0101EN'},
#  {'user': 1935753, 'item': 'DV0101EN'},
#  {'user': 1456410, 'item': 'DA0101EN'},
#  {'user': 1452402, 'item': 'DS0101EN'},
#  {'user': 1570208, 'item': 'DS0101EN'},
#  {'user': 682652, 'item': 'DA0101EN'},
#  {'user': 978279, 'item': 'ML0101ENv3'},
#  {'user': 1049471, 'item': 'BD0101EN'},
#  {'user': 1730573, 'item': 'ML0101ENv3'},
#  {'user': 1858250, 'item': 'DV0101EN'},
#  {'user': 704583, 'item': 'DA0101EN'},
#  {'user': 896335, 'item': 'DS0101EN'},
#  {'user': 373076, 'item': 'DS0101EN'},
#  {'user': 606214, 'item': 'DV0101EN'},
#  {'user': 1238107, 'item': 'DV0101EN'},
#  {'user': 1499966, 'item': 'ML0101ENv3'},
#  {'user': 1919984, 'item': 'DA0101EN'},
#  {'user': 2056704, 'item': 'DA0101EN'},
#  {'user': 1717303, 'item': 'BD0101EN'},
#  {'user': 1196755, 'item': 'DA0101EN'},
#  {'user': 1328233, 'item': 'DS0101EN'},
#  {'user': 911789, 'item': 'DS0101EN'},
#  {'user': 1897898, 'item': 'DS0101EN'},
#  {'user': 673206, 'item': 'DA0101EN'},
#  {'user': 1493943, 'item': 'DA0101EN'},
#  {'user': 1194346, 'item': 'DS0101EN'},
#  {'user': 1000886, 'item': 'DS0101EN'},
#  {'user': 1889420, 'item': 'DV0101EN'},
#  {'user': 1627236, 'item': 'DS0101EN'},
#  {'user': 1287646, 'item': 'DS0101EN'},
#  {'user': 942261, 'item': 'DA0101EN'},
#  {'user': 1955349, 'item': 'ML0101ENv3'},
#  {'user': 371091, 'item': 'DA0101EN'},
#  {'user': 1664399, 'item': 'DS0101EN'},
#  {'user': 1431881, 'item': 'ML0101ENv3'},
#  {'user': 1840749, 'item': 'DS0101EN'},
#  {'user': 1781984, 'item': 'DS0101EN'},
#  {'user': 1578866, 'item': 'DS0101EN'},
#  {'user': 1887480, 'item': 'ML0101ENv3'},
#  {'user': 609064, 'item': 'DA0101EN'},
#  {'user': 2032910, 'item': 'CB0103EN'},
#  {'user': 1758996, 'item': 'DS0101EN'},
#  {'user': 1121636, 'item': 'DS0101EN'},
#  {'user': 576397, 'item': 'DA0101EN'},
#  {'user': 1907898, 'item': 'DS0101EN'},
#  {'user': 1390057, 'item': 'CB0103EN'},
#  {'user': 1021071, 'item': 'DV0101EN'},
#  {'user': 625223, 'item': 'DS0101EN'},
#  {'user': 1830259, 'item': 'DS0101EN'},
#  {'user': 1474724, 'item': 'BD0211EN'},
#  {'user': 1344813, 'item': 'DA0101EN'},
#  {'user': 481658, 'item': 'BD0211EN'},
#  {'user': 630511, 'item': 'DS0101EN'}]

# %% [markdown]
# With the recommendation results, you also need to write some analytic code to answer the following two questions:

# %% [markdown]
# *   On average, how many new/unseen courses have been recommended to each user?
# *   What are the most frequently recommended courses? Return the top-10 commonly recommended courses across all users.

# %% [markdown]
# For example, suppose we have only 3 test users, each user receives the following recommendations:

# %% [markdown]
# *   User1: \['course1', 'course2']
# *   User2: \['course3', 'course4']
# *   User3: \['course3', 'course4', 'course5']

# %% [markdown]
# Then, the average recommended courses per user is $(2 + 2 + 3) / 3 = 2.33$. The top-2 recommended courses are: `course3`: 2 times, and `course4`: 2 times.

# %% [markdown]
# Note that the answers will depend on how you compute the popular courses for each cluster. A lower threshold yields more recommended courses but with smaller confidence so that some test users may receive very long course recommendation lists and feel overwhelmed.
#
# Ideally, we should limit the maximum course recommendations for each user to be less than 20 courses per user.

# %% [markdown]
# ### Explore other clustering algorithms

# %% [markdown]
# As you have learned in previous unsupervised learning course, there are many other clustering algorithms such as `DBSCAN` and `Hierarchical Clustering`. You are encouraged to try them on the user profile feature vectors and compare the results with K-means.

# %% [markdown]
# ### Summary

# %% [markdown]
# Congratulations! In this lab, you have applied clustering algorithms to group users with similar interests and also tried PCA to reduce the dimensions of user feature vectors.
#
# Furthermore, with each user finding its learning interest group, you have also implemented clustering-based course recommender system to make recommendations based on his/her group members' popular courses choices.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML321ENSkillsNetwork32585014-2022-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-10-25        | 1.0     | Yan        | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
